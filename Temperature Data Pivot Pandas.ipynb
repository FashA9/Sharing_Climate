# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Lenovo

# %%
import pandas as pd
import numpy as np

# %%
import csv
data = open(r"C:\Users\Lenovo\Downloads\Environment_Temperature_change_E_All_Data\Environment_Temperature_change_E_All_Data.csv")
data2 = csv.reader(data)  
print(data2)

data2

# %%
import csv
with open('Environment_Temperature_change_E_All_Data.csv','r')as file:
   filecontent=csv.reader(file)
   for row in filecontent:
        print(row)
# Out:
# ['ï»¿Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element', 'Unit', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Y2019', 'Y2020', 'Y2021']
# ...

# %%
mydata = pd.read_csv("Environment_Temperature_change_E_All_Data.csv")
mydata
# Out:
#       Area Code         Area  Months Code               Months  Element Code  \
# 0             2  Afghanistan         7001              January          7271
# 1             2  Afghanistan         7001              January          6078
# 2             2  Afghanistan         7002             February          7271
# 3             2  Afghanistan         7002             February          6078
# 4             2  Afghanistan         7003                March          7271
# ...         ...          ...          ...                  ...           ...
# 9651       5873         OECD         7018          Jun–Jul–Aug          6078
# 9652       5873         OECD         7019          Sep–Oct–Nov          7271
# 9653       5873         OECD         7019          Sep–Oct–Nov          6078
# 9654       5873         OECD         7020  Meteorological year          7271
# 9655       5873         OECD         7020  Meteorological year          6078
#
# ...

# %%
mydata2 = mydata.loc[mydata['Element'] == "Temperature change"]
mydata2
# Out:
#       Area Code         Area  Months Code               Months  Element Code  \
# 0             2  Afghanistan         7001              January          7271
# 2             2  Afghanistan         7002             February          7271
# 4             2  Afghanistan         7003                March          7271
# 6             2  Afghanistan         7004                April          7271
# 8             2  Afghanistan         7005                  May          7271
# ...         ...          ...          ...                  ...           ...
# 9646       5873         OECD         7016          Dec–Jan–Feb          7271
# 9648       5873         OECD         7017          Mar–Apr–May          7271
# 9650       5873         OECD         7018          Jun–Jul–Aug          7271
# 9652       5873         OECD         7019          Sep–Oct–Nov          7271
# 9654       5873         OECD         7020  Meteorological year          7271
#
# ...

# %%
stacked = mydata2.stack()
stacked
# Out:
# 0     Area Code                 2
#       Area            Afghanistan
#       Months Code            7001
#       Months              January
#       Element Code           7271
#                          ...
# 9654  Y2017                 1.363
#       Y2018                 1.093
#       Y2019                 1.301
#       Y2020                 1.438
#       Y2021                 1.453
# Length: 297041, dtype: object

# %%
unstacked= stacked.unstack()
unstacked
# Out:
#      Area Code         Area Months Code               Months Element Code  \
# 0            2  Afghanistan        7001              January         7271
# 2            2  Afghanistan        7002             February         7271
# 4            2  Afghanistan        7003                March         7271
# 6            2  Afghanistan        7004                April         7271
# 8            2  Afghanistan        7005                  May         7271
# ...        ...          ...         ...                  ...          ...
# 9646      5873         OECD        7016          Dec–Jan–Feb         7271
# 9648      5873         OECD        7017          Mar–Apr–May         7271
# 9650      5873         OECD        7018          Jun–Jul–Aug         7271
# 9652      5873         OECD        7019          Sep–Oct–Nov         7271
# 9654      5873         OECD        7020  Meteorological year         7271
#
#                  Element Unit  Y1961  Y1962  Y1963  ...  Y2012  Y2013  Y2014  \
# ...

# %%
mydata3 = mydata2.drop(['Area Code', 'Months Code', 'Element Code', 'Element', 'Unit'], axis=1)
mydata3.head()
# Out:
#           Area    Months  Y1961  Y1962  Y1963  Y1964  Y1965  Y1966  Y1967  \
# 0  Afghanistan   January  0.786  0.039  2.718 -5.226  1.889  3.638 -1.429
# 2  Afghanistan  February -1.762  2.423  3.880 -0.209 -0.090  3.383  0.282
# 4  Afghanistan     March  0.477  1.293  0.391  1.655 -0.897 -0.076 -0.768
# 6  Afghanistan     April -1.745  0.066  0.881 -0.565 -1.835 -1.224 -1.530
# 8  Afghanistan       May  1.365 -0.140 -0.739 -0.173 -0.191 -0.210 -1.321
#
#    Y1968  ...  Y2012  Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019  Y2020  \
# 0  0.394  ... -0.425  1.368  1.761  1.937  3.612  1.273  2.127  2.978 -0.584
# 2 -2.071  ... -3.066  1.615 -3.110  2.592  2.454 -0.189  2.760  0.112  2.548
# 4  0.486  ... -0.366  2.369 -0.061 -0.545  2.459  0.923  4.580  0.354  0.611
# 6 -0.619  ...  1.549  0.037  0.601  1.641  1.004  1.303  1.417  0.981  0.036
# 8 -1.857  ...  1.065  1.299  0.976  1.918  3.339  3.408  0.872  0.536  1.132
#
#    Y2021
# 0  0.558
# 2  4.149
# 4  2.557
# 6  2.197
# ...

# %%
stacked2 = mydata3.stack()
stacked2
# Out:
# 0     Area      Afghanistan
#       Months        January
#       Y1961           0.786
#       Y1962           0.039
#       Y1963           2.718
#                    ...
# 9654  Y2017           1.363
#       Y2018           1.093
#       Y2019           1.301
#       Y2020           1.438
#       Y2021           1.453
# Length: 272901, dtype: object

# %%
# For this dataset, this is every non-numeric column
idx =['Area','Months']
      
# Then pivot the dataset based on this multi-level index 
multi_indexed_df = mydata3.set_index(idx)
multi_indexed_df.head(2)
# Out:
#                       Y1961  Y1962  Y1963  Y1964  Y1965  Y1966  Y1967  Y1968  \
# Area        Months
# Afghanistan January   0.786  0.039  2.718 -5.226  1.889  3.638 -1.429  0.394
#             February -1.762  2.423  3.880 -0.209 -0.090  3.383  0.282 -2.071
#
#                       Y1969  Y1970  ...  Y2012  Y2013  Y2014  Y2015  Y2016  \
# Area        Months                  ...
# Afghanistan January  -2.524  0.824  ... -0.425  1.368  1.761  1.937  3.612
#             February -3.436  2.101  ... -3.066  1.615 -3.110  2.592  2.454
#
#                       Y2017  Y2018  Y2019  Y2020  Y2021
# Area        Months
# Afghanistan January   1.273  2.127  2.978 -0.584  0.558
#             February -0.189  2.760  0.112  2.548  4.149
#
# [2 rows x 61 columns]

# %%
stacked_df = multi_indexed_df.stack(dropna=False)
stacked_df.head(25) # check out the results!
# Out:
# Area         Months
# Afghanistan  January  Y1961    0.786
#                       Y1962    0.039
#                       Y1963    2.718
#                       Y1964   -5.226
#                       Y1965    1.889
#                       Y1966    3.638
#                       Y1967   -1.429
#                       Y1968    0.394
#                       Y1969   -2.524
#                       Y1970    0.824
#                       Y1971   -1.465
#                       Y1972   -1.237
#                       Y1973   -2.871
#                       Y1974   -1.181
#                       Y1975   -0.499
#                       Y1976    2.404
#                       Y1977   -2.902
#                       Y1978   -0.608
#                       Y1979    1.069
#                       Y1980   -0.348
#                       Y1981    1.871
#                       Y1982    0.828
#                       Y1983    0.609
#                       Y1984    0.018
#                       Y1985    0.588
# ...

# %%
#reshape DataFrame from wide format to long format
mydata4 = pd.melt(mydata3, id_vars = ['Area', 'Months'], var_name = 'Year', value_name = 'Temperature(C)')

#view updated DataFrame
mydata4
# Out:
#                Area               Months   Year  Temperature(C)
# 0       Afghanistan              January  Y1961           0.786
# 1       Afghanistan             February  Y1961          -1.762
# 2       Afghanistan                March  Y1961           0.477
# 3       Afghanistan                April  Y1961          -1.745
# 4       Afghanistan                  May  Y1961           1.365
# ...             ...                  ...    ...             ...
# 294503         OECD          Dec–Jan–Feb  Y2021           1.790
# 294504         OECD          Mar–Apr–May  Y2021           1.073
# 294505         OECD          Jun–Jul–Aug  Y2021           1.388
# 294506         OECD          Sep–Oct–Nov  Y2021           1.563
# 294507         OECD  Meteorological year  Y2021           1.453
#
# [294508 rows x 4 columns]

# %%
mydata4["Year"] = mydata4["Year"].str.replace("Y","")
mydata4
# Out:
#                Area               Months  Year  Temperature(C)
# 0       Afghanistan              January  1961           0.786
# 1       Afghanistan             February  1961          -1.762
# 2       Afghanistan                March  1961           0.477
# 3       Afghanistan                April  1961          -1.745
# 4       Afghanistan                  May  1961           1.365
# ...             ...                  ...   ...             ...
# 294503         OECD          Dec–Jan–Feb  2021           1.790
# 294504         OECD          Mar–Apr–May  2021           1.073
# 294505         OECD          Jun–Jul–Aug  2021           1.388
# 294506         OECD          Sep–Oct–Nov  2021           1.563
# 294507         OECD  Meteorological year  2021           1.453
#
# [294508 rows x 4 columns]

# %% [markdown]
# #combine month & year
# mydata4["Date"] = pd.to_datetime(mydata4["Year"] + "/" + mydata4["Months"]
# mydata4

# %%
# consider the list
list1 = ['Dec–Jan–Feb', 'Mar–Apr–May', 'Jun–Jul–Aug', 'Jun–Jul–Aug', 'Sep–Oct–Nov', 'Meteorological year']

# drop rows from above list
mydata5 =mydata4[mydata4.Months.isin(list1) == False]
mydata5
# Out:
#                Area     Months  Year  Temperature(C)
# 0       Afghanistan    January  1961           0.786
# 1       Afghanistan   February  1961          -1.762
# 2       Afghanistan      March  1961           0.477
# 3       Afghanistan      April  1961          -1.745
# 4       Afghanistan        May  1961           1.365
# ...             ...        ...   ...             ...
# 294498         OECD     August  2021           1.156
# 294499         OECD  September  2021           1.451
# 294500         OECD    October  2021           2.049
# 294501         OECD   November  2021           1.190
# 294502         OECD   December  2021           1.563
#
# [207888 rows x 4 columns]

# %%
#drop missing values
mydata6 = mydata5.dropna()
mydata6
# Out:
#                Area     Months  Year  Temperature(C)
# 0       Afghanistan    January  1961           0.786
# 1       Afghanistan   February  1961          -1.762
# 2       Afghanistan      March  1961           0.477
# 3       Afghanistan      April  1961          -1.745
# 4       Afghanistan        May  1961           1.365
# ...             ...        ...   ...             ...
# 294498         OECD     August  2021           1.156
# 294499         OECD  September  2021           1.451
# 294500         OECD    October  2021           2.049
# 294501         OECD   November  2021           1.190
# 294502         OECD   December  2021           1.563
#
# [185788 rows x 4 columns]

# %%
#combine month & year 
mydata6["Date"] = pd.to_datetime(mydata6["Year"] + "/" + mydata6["Months"])
mydata6

#set Date as index in timeseries
# making Data as an Index
mydata6.set_index('Date')
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    Area     Months  Year  Temperature(C)
# Date
# 1961-01-01  Afghanistan    January  1961           0.786
# 1961-02-01  Afghanistan   February  1961          -1.762
# 1961-03-01  Afghanistan      March  1961           0.477
# 1961-04-01  Afghanistan      April  1961          -1.745
# 1961-05-01  Afghanistan        May  1961           1.365
# ...                 ...        ...   ...             ...
# 2021-08-01         OECD     August  2021           1.156
# 2021-09-01         OECD  September  2021           1.451
# 2021-10-01         OECD    October  2021           2.049
# ...

# %%
list2 = ['United Kingdom of Great Britain and Northern Ireland', 'France', 'Iran', 'Canada', 'Europe', 'Iceland', 'Malaysia', 'Philipines', 'Singapore', 'Indonesia', 'Brazil', 'Iceland', 'World', 'OECD', 'America', 'Western Asia', 'Asia', 'Central Asia', 'Africa', 'Australia', 'China', 'India']

# selecting rows based on condition 
mydata7 = mydata6[mydata6['Area'].isin(list2)] 
mydata7
# Out:
#              Area     Months  Year  Temperature(C)       Date
# 204     Australia    January  1961           0.280 1961-01-01
# 205     Australia   February  1961           0.008 1961-02-01
# 206     Australia      March  1961           0.249 1961-03-01
# 207     Australia      April  1961           0.691 1961-04-01
# 208     Australia        May  1961          -0.161 1961-05-01
# ...           ...        ...   ...             ...        ...
# 294498       OECD     August  2021           1.156 2021-08-01
# 294499       OECD  September  2021           1.451 2021-09-01
# 294500       OECD    October  2021           2.049 2021-10-01
# 294501       OECD   November  2021           1.190 2021-11-01
# 294502       OECD   December  2021           1.563 2021-12-01
#
# [12421 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

 
# Create a grid : initialize it
g = sns.FacetGrid(mydata7, col='Area', hue='Area', col_wrap=1, height=3, aspect=5)

# Add the line over the area with the plot function
g = g.map(plt.plot, 'Date', 'Temperature(C)')
 
# Fill the area with fill_between
g = g.map(plt.fill_between, 'Date', 'Temperature(C)', alpha=0.2).set_titles("{col_name} Area")
 
# Control the title of each facet
g = g.set_titles("{col_name}")

# Add a title for the whole plot
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Temperature change by country')


# Show the graph
plt.show()

# %%
# library
import seaborn as sns
import pandas as pd
import numpy as np
 

# Turn long format into a wide format
mydata7_wide = mydata7.pivot_table( index='Area', columns='Year', values='Temperature(C)')


# plot it
plt.figure(figsize = (15,8))
sns.heatmap(mydata7_wide, center = 0)

# %%
# libraries
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
 
# Create a dataset
my_count=["France","Australia","Japan","USA","Germany","Congo","China","England","Spain","Greece","Marocco","South Africa","Indonesia","Peru","Chili","Brazil"]
df = pd.DataFrame({
"country":np.repeat(my_count, 10),
"years":list(range(2000, 2010)) * 16,
"value":np.random.rand(160)
})
 
# Create a grid : initialize it
g = sns.FacetGrid(df, col='country', hue='country', col_wrap=4, )

# Add the line over the area with the plot function
g = g.map(plt.plot, 'years', 'value')
 
# Fill the area with fill_between
g = g.map(plt.fill_between, 'years', 'value', alpha=0.2).set_titles("{col_name} country")
 
# Control the title of each facet
g = g.set_titles("{col_name}")
 
# Add a title for the whole plot
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Evolution of the value of stuff in 16 countries')

# Show the graph
plt.show()

# %%
# library
import seaborn as sns
import pandas as pd
import numpy as np
 
# Create long format
people = np.repeat(("A","B","C","D","E"),5)
feature = list(range(1,6))*5
value = np.random.random(25)
df = pd.DataFrame({'feature': feature, 'people': people, 'value': value })


# Turn long format into a wide format
df_wide = df.pivot_table( index='people', columns='feature', values='value')


# plot it
sns.heatmap(df_wide)

# %%
df
# Out:
#     feature people     value
# 0         1      A  0.235914
# 1         2      A  0.030711
# 2         3      A  0.291288
# 3         4      A  0.814598
# 4         5      A  0.658915
# 5         1      B  0.946146
# 6         2      B  0.297006
# 7         3      B  0.220825
# 8         4      B  0.587818
# 9         5      B  0.073320
# 10        1      C  0.115573
# 11        2      C  0.606940
# 12        3      C  0.440062
# 13        4      C  0.610720
# 14        5      C  0.866960
# 15        1      D  0.852283
# 16        2      D  0.544034
# 17        3      D  0.698888
# 18        4      D  0.305883
# 19        5      D  0.947474
# 20        1      E  0.218063
# 21        2      E  0.687342
# 22        3      E  0.093809
# 23        4      E  0.370306
# 24        5      E  0.424927

# %%
df_wide
# Out:
# feature         1         2         3         4         5
# people
# A        0.235914  0.030711  0.291288  0.814598  0.658915
# B        0.946146  0.297006  0.220825  0.587818  0.073320
# C        0.115573  0.606940  0.440062  0.610720  0.866960
# D        0.852283  0.544034  0.698888  0.305883  0.947474
# E        0.218063  0.687342  0.093809  0.370306  0.424927
